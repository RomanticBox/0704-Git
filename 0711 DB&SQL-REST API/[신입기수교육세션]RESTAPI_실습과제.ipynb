# %% [markdown]
# # REST API 실습
#
# 22th DE 김원

# %% [markdown]
# ## Python에서

# %%
import requests
# GET 요청 보내기
response = requests.get('https://reqres.in/api/users?page=2')

# 응답 확인
if response.status_code == 200:
    res = response.json()
    print(res)
else:
    print('요청에 실패했습니다. 상태 코드:', res.status_code)
# Out:
# {'page': 2, 'per_page': 6, 'total': 12, 'total_pages': 2, 'data': [{'id': 7, 'email': 'michael.lawson@reqres.in', 'first_name': 'Michael', 'last_name': 'Lawson', 'avatar': 'https://reqres.in/img/faces/7-image.jpg'}, {'id': 8, 'email': 'lindsay.ferguson@reqres.in', 'first_name': 'Lindsay', 'last_name': 'Ferguson', 'avatar': 'https://reqres.in/img/faces/8-image.jpg'}, {'id': 9, 'email': 'tobias.funke@reqres.in', 'first_name': 'Tobias', 'last_name': 'Funke', 'avatar': 'https://reqres.in/img/faces/9-image.jpg'}, {'id': 10, 'email': 'byron.fields@reqres.in', 'first_name': 'Byron', 'last_name': 'Fields', 'avatar': 'https://reqres.in/img/faces/10-image.jpg'}, {'id': 11, 'email': 'george.edwards@reqres.in', 'first_name': 'George', 'last_name': 'Edwards', 'avatar': 'https://reqres.in/img/faces/11-image.jpg'}, {'id': 12, 'email': 'rachel.howell@reqres.in', 'first_name': 'Rachel', 'last_name': 'Howell', 'avatar': 'https://reqres.in/img/faces/12-image.jpg'}], 'support': {'url': 'https://reqres.in/#support-heading', 'text': 'To keep ReqRes free, contributions towards server costs are appreciated!'}}

# %%
res
# Out:
# {'page': 2,
#  'per_page': 6,
#  'total': 12,
#  'total_pages': 2,
#  'data': [{'id': 7,
#    'email': 'michael.lawson@reqres.in',
#    'first_name': 'Michael',
#    'last_name': 'Lawson',
#    'avatar': 'https://reqres.in/img/faces/7-image.jpg'},
#   {'id': 8,
#    'email': 'lindsay.ferguson@reqres.in',
#    'first_name': 'Lindsay',
#    'last_name': 'Ferguson',
#    'avatar': 'https://reqres.in/img/faces/8-image.jpg'},
#   {'id': 9,
#    'email': 'tobias.funke@reqres.in',
#    'first_name': 'Tobias',
#    'last_name': 'Funke',
#    'avatar': 'https://reqres.in/img/faces/9-image.jpg'},
#   {'id': 10,
#    'email': 'byron.fields@reqres.in',
#    'first_name': 'Byron',
#    'last_name': 'Fields',
#    'avatar': 'https://reqres.in/img/faces/10-image.jpg'},
#   {'id': 11,
#    'email': 'george.edwards@reqres.in',
#    'first_name': 'George',
#    'last_name': 'Edwards',
#    'avatar': 'https://reqres.in/img/faces/11-image.jpg'},
#   {'id': 12,
#    'email': 'rachel.howell@reqres.in',
#    'first_name': 'Rachel',
#    'last_name': 'Howell',
#    'avatar': 'https://reqres.in/img/faces/12-image.jpg'}],
#  'support': {'url': 'https://reqres.in/#support-heading',
#   'text': 'To keep ReqRes free, contributions towards server costs are appreciated!'}}

# %%
res['data'][0]
# Out:
# {'id': 7,
#  'email': 'michael.lawson@reqres.in',
#  'first_name': 'Michael',
#  'last_name': 'Lawson',
#  'avatar': 'https://reqres.in/img/faces/7-image.jpg'}

# %%
import pandas as pd
df = pd.DataFrame(res['data'])
df
# Out:
#    id                       email first_name last_name  \
# 0   7    michael.lawson@reqres.in    Michael    Lawson
# 1   8  lindsay.ferguson@reqres.in    Lindsay  Ferguson
# 2   9      tobias.funke@reqres.in     Tobias     Funke
# 3  10      byron.fields@reqres.in      Byron    Fields
# 4  11    george.edwards@reqres.in     George   Edwards
# 5  12     rachel.howell@reqres.in     Rachel    Howell
#
#                                      avatar
# 0   https://reqres.in/img/faces/7-image.jpg
# 1   https://reqres.in/img/faces/8-image.jpg
# 2   https://reqres.in/img/faces/9-image.jpg
# 3  https://reqres.in/img/faces/10-image.jpg
# 4  https://reqres.in/img/faces/11-image.jpg
# 5  https://reqres.in/img/faces/12-image.jpg

# %% [markdown]
# ## terminal에서

# %% [markdown]
# 가장 간단한 요청입니다 curl + 요청을 보낼 주소 위는 코랩이기 때문에 터미널명령어를 !앞에 붙여 실행합니다 터미널에서는 !안붙여도 괜찮아요!!

# %%
# !curl https://reqres.in/api/users?page=2

# %% [markdown]
# Curl에 여러가지 옵션을 추가할 수 있습니다
#
# -X : HTTP 메서드 지정
# <br>
#
# GET: 리소스를 가져오기 위한 요청입니다. 기본적으로 curl이 사용하는 메서드입니다.<br>
# POST: 리소스를 생성하기 위한 요청입니다. 데이터를 서버로 전송할 때 사용됩니다.<br>
# PUT: 리소스를 수정하기 위한 요청입니다. 전체 리소스를 업데이트합니다.<br>
# PATCH: 리소스를 일부 수정하기 위한 요청입니다. 부분적인 업데이트를 수행할 때 사용됩니다.<br>
# DELETE: 리소스를 삭제하기 위한 요청입니다.
#
# <br>
#
# -H : header 설정 header란 무엇일까? - 범위를 벗어나므로 신원을 확인하거나, 추가적인 정보가 담겨있는 부분: <br> => 메타데이터가 담겨있는 부분입니다!  <br>
#
# -d : data의 약자로 데이터를 넘겨줍니다
#
#
# <br>
#
# 아래의 예시의 경우, 게시판 홈페이지에 사람을 추가하는 예시! <br>
#
# 리소스를 생성하기 때문에 POST method로, 추가해야할 데이터를 -d 인자로 넘겨줍니다

# %%
# !curl -X POST -H "Content-Type: application/json" -d '{"name": "John", "age":30}' https://reqres.in/api/users

# %% [markdown]
# 위 코드를 실행하면, 정상응답이 나오는 경우 reqres.in 페이지에 /api/users에 새로운 유저를 등록 요청하는 request입니다!

# %% [markdown]
# ### 위를 파이썬 버전으로

# %%
import requests
import json

url = 'https://reqres.in/api/users'
headers = {'Content-Type': 'application/json'}
data = {'name': 'John', 'age': 30}


# post method로 요청

response = requests.post(url, headers=headers, data=json.dumps(data))

if response.status_code == 201: # 상태코드가 201이라면(201 : 요청 정상처리 상태코드 )
    result = response.json()
    print('사용자 생성 완료:', result)
else:
    print('요청에 실패했습니다. 상태 코드:', response.status_code)
# Out:
# 사용자 생성 완료: {'name': 'John', 'age': 30, 'id': '674', 'createdAt': '2023-07-17T14:40:13.361Z'}

# %%
res['data'][0]
# Out:
# {'id': 7,
#  'email': 'michael.lawson@reqres.in',
#  'first_name': 'Michael',
#  'last_name': 'Lawson',
#  'avatar': 'https://reqres.in/img/faces/7-image.jpg'}

# %% [markdown]
# # 페이지를 순회하며 데이터 프레임 만들기! + 약간의 전처리

# %%
import requests
# GET 요청 보내기
response = requests.get('https://reqres.in/api/users?page=2')

# 응답 확인
if response.status_code == 200:
    res = response.json()
    print(res)
else:
    print('요청에 실패했습니다. 상태 코드:', res.status_code)
# Out:
# {'page': 2, 'per_page': 6, 'total': 12, 'total_pages': 2, 'data': [{'id': 7, 'email': 'michael.lawson@reqres.in', 'first_name': 'Michael', 'last_name': 'Lawson', 'avatar': 'https://reqres.in/img/faces/7-image.jpg'}, {'id': 8, 'email': 'lindsay.ferguson@reqres.in', 'first_name': 'Lindsay', 'last_name': 'Ferguson', 'avatar': 'https://reqres.in/img/faces/8-image.jpg'}, {'id': 9, 'email': 'tobias.funke@reqres.in', 'first_name': 'Tobias', 'last_name': 'Funke', 'avatar': 'https://reqres.in/img/faces/9-image.jpg'}, {'id': 10, 'email': 'byron.fields@reqres.in', 'first_name': 'Byron', 'last_name': 'Fields', 'avatar': 'https://reqres.in/img/faces/10-image.jpg'}, {'id': 11, 'email': 'george.edwards@reqres.in', 'first_name': 'George', 'last_name': 'Edwards', 'avatar': 'https://reqres.in/img/faces/11-image.jpg'}, {'id': 12, 'email': 'rachel.howell@reqres.in', 'first_name': 'Rachel', 'last_name': 'Howell', 'avatar': 'https://reqres.in/img/faces/12-image.jpg'}], 'support': {'url': 'https://reqres.in/#support-heading', 'text': 'To keep ReqRes free, contributions towards server costs are appreciated!'}}

# %% [markdown]
# # 원래 여러분들이 사용하실 때는...
#
# 보통 API의 호출양이 지정되어 있어서, API 세션 아이디, 키가 보통 필요해요!
#
# </br>
#
# 밑에 하고자 했던 코드는 여러페이지에 걸쳐 순회해서 데이터프레임으로 만드는 과정을 보여드리려고했는데,
# 저게 api가 연습용 서버여서 조금 호출 횟수에 제한된 것 같네요!! 원래 1페이지 부터 11페이지까지 6 x 11 행이 나와야하는데, 무료이다보니 서버에 부담이 되어 time.sleep(5)로 해봤는데도 안되네요! 하여튼 예시로 참고하면 좋을 것 같습니다!

# %%
import requests
import pandas as pd
import time

# 빈 데이터프레임 생성
df_combined = pd.DataFrame()

# 페이지 순회
for page in range(1, 11):
    # GET 요청 보내기
    url = f'https://reqres.in/api/users?page={page}'
    response = requests.get(url)

    # 응답 확인
    if response.status_code == 200:
        data = response.json()
        users = data['data']

        # 데이터프레임으로 변환
        df = pd.DataFrame(users)

        # 데이터프레임 결합
        df_combined = pd.concat([df_combined, df], ignore_index=True)
    else:
        print(f'페이지 {page} 요청에 실패했습니다. 상태 코드:', response.status_code)

# 합쳐진 데이터프레임 출력 (아쉽게도 안됨)
df_combined
# Out:
#     id                       email first_name last_name  \
# 0    1      george.bluth@reqres.in     George     Bluth
# 1    2      janet.weaver@reqres.in      Janet    Weaver
# 2    3         emma.wong@reqres.in       Emma      Wong
# 3    4          eve.holt@reqres.in        Eve      Holt
# 4    5    charles.morris@reqres.in    Charles    Morris
# 5    6      tracey.ramos@reqres.in     Tracey     Ramos
# 6    7    michael.lawson@reqres.in    Michael    Lawson
# 7    8  lindsay.ferguson@reqres.in    Lindsay  Ferguson
# 8    9      tobias.funke@reqres.in     Tobias     Funke
# 9   10      byron.fields@reqres.in      Byron    Fields
# 10  11    george.edwards@reqres.in     George   Edwards
# 11  12     rachel.howell@reqres.in     Rachel    Howell
#
#                                       avatar
# 0    https://reqres.in/img/faces/1-image.jpg
# 1    https://reqres.in/img/faces/2-image.jpg
# 2    https://reqres.in/img/faces/3-image.jpg
# 3    https://reqres.in/img/faces/4-image.jpg
# 4    https://reqres.in/img/faces/5-image.jpg
# 5    https://reqres.in/img/faces/6-image.jpg
# 6    https://reqres.in/img/faces/7-image.jpg
# 7    https://reqres.in/img/faces/8-image.jpg
# 8    https://reqres.in/img/faces/9-image.jpg
# 9   https://reqres.in/img/faces/10-image.jpg
# 10  https://reqres.in/img/faces/11-image.jpg
# 11  https://reqres.in/img/faces/12-image.jpg

# %% [markdown]
# # 과제 !! 나쁜 사람 아닙니다
#
#
# **개념 요약!! 아래 마크다운을 채워주세요 !! **
#
# 챗지피티 사용금지

# %% [markdown]
# ## API란 -> Application Programming Interface의 줄임말로, 애플리케이션 간의 정보를 교환할 때 일정한 규칙에 따라 정보를 교환할 수 있도록 하는 방식.
#
# ## REST API란 -> REpresentational State Transfer Application Programming Interface의 줄임말로, 서버의 어떤 정보의 연산을 수행하기 위해 정해진 의사소통 규칙인 API를 따라 서버에 요청하는 것.
#
# ## 각각에 대응하는 HTTP의 메서드를 적어주세요
#
# ### Create -> 리소스 조회(GET)
# ### Read -> 리소스 등록(POST)
# ### Update -> 리소스 대체 없으면 생성(PUT) / 리소스 부분 변경(PATCH)
# ### Delete -> 리소스 삭제(DELETE)

# %% [markdown]
# ## 실습 과제 1 공식문서를 읽고 아래의 예시코드에 파라미터를 바꿔서 보낸 결과 확인하기!!
#
# 공식문서에 파라미터들을 직접 넘겨줘서 요청을 보내면 됩니다!

# %% [markdown]
# <https://punkapi.com/documentation/v2>

# %%
# !curl https://api.punkapi.com/v2/beers

# %% [markdown]
# ```
# response = requests.get('https://reqres.in/api/users?page=2&per_page=10')
# response.get(url,params= {'page': 2, 'per_page':10 })
# ```
#
#
#
# 위에 두개는 같은 요청입니다! 뒤에 파라미터들이 ?으로 , 파라미터가 여러개일 경우 &으로 연결됩니다!

# %%
import requests
import json
import time

url = 'https://api.punkapi.com/v2/beers'
headers = {'Content-Type': 'application/json'}
# 파라미터로 인자 넘겨줄 수 있음!!
# 아래 params 코드에 인자들을 공식문서를 확인하여 추가하시거나 바꿔주세요!!
params= {'page': 3, 'abv':20 }

response = requests.get(url, headers=headers,params=params)

if reponse.status_code == 200:
    result = response.json()
    print('받아온 데이터:', result)
else:
    print('요청에 실패했습니다. 상태 코드:', response.status_code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 13
#       9 params= {'page': 3, 'abv':20 }
#      11 response = requests.get(url, headers=headers,params=params)
# ---> 13 if reponse.status_code == 200:
#      14     result = response.json()
#      15     print('받아온 데이터:', result)
#
# NameError: name 'reponse' is not defined

# %%
import pandas as pd

df = pd.DataFrame(result)
df
# Out:
#     id                                               name  \
# 0   51                                               TM10
# 1   52                                      Paradox Islay
# 2   53                                         Baby Dogma
# 3   54                               Albino Squid Assasin
# 4   55                             Amarillo - IPA Is Dead
# 5   56                                Black Eyed King Imp
# 6   57                                       Prototype 27
# 7   58                              Coffee Imperial Stout
# 8   59                    Mandarina Bavaria - IPA Is Dead
# 9   60                                              Dogma
# 10  61  Magic Stone Dog (w/Magic Rock & Stone Brewing ...
# 11  62                                              AB:08
# 12  63                                          Sunk Punk
# 13  64                                            Sub Hop
# 14  65                                   Bracken's Porter
# 15  66                         Tokyo Rising Sun - Lowland
# 16  67                         Hunter Foundation Pale Ale
# 17  68                                               Hype
# 18  69                                              AB:16
# 19  70                                      Sunmaid Stout
# 20  71                                Pale - Russian Doll
# 21  72                              Whisky Sour - B-Sides
# 22  73    Black Eyed King Imp - Vietnamese Coffee Edition
# 23  74                                          Eurotrash
# 24  75                           Never Mind The Anabolics
#
#                                               tagline first_brewed  \
# 0                                         Liquid Art.      04/2010
# 1                          Ubiquitous Imperial Stout.      04/2007
# 2                                 Session Scotch Ale.      09/2013
# 3                                         Red Rye IPA      11/2015
# 4                          Single Hop India Pale Ale.      01/2013
# 5                 Barrel-Aged Prototype Cocoa Psycho.      11/2012
# 6                             Vibrant Smoky Pink IPA.      04/2010
# 7                                 Beats a Cup of Joe.      11/2008
# 8                          Single Hop India Pale Ale.      03/2015
# 9        Revamped Wee Heavy. Luscious. Malty. Fruity.      07/2013
# 10  Session Farmhouse IPA - Stone / Magic Rock Col...      06/2014
# 11               Deconstructed Blonde Imperial Stout.      11/2011
# 12                             Ocean Fermented Lager.      09/2011
# 13                        Hopped-Up Imperial Pilsner.      06/2014
# 14         A Tribute To Our Favourite 4 Pawed Friend.      03/2013
# 15                              A Beautiful Accident.      06/2009
# 16                                 American Pale Ale.      05/2012
# 17                              New Zealand Pale Ale.      08/2007
# 18                       Coffee-Infused Belgian Quad.      02/2014
# 19                       Rum & Raisin Imperial Stout.      12/2011
# 20                                  Nesting Hop Bomb.      08/2014
# 21            Pilot Brew - Deconstructed Whisky Sour.      03/2015
# 22                         Vietnamese Coffee Edition.      12/2014
# 23                                    Belgian Blonde.      10/2009
# 24              Performance-Enhancing India Pale Ale.      06/2012
#
#                                           description  \
# 0   Brewed for the Tate Modern’s 10th Anniversary....
# 1   In 2006 James and Martin hijacked a beer dinne...
# 2   A baby Scotch ale with dry and toasty malt fla...
# 3   This tentacled terminator packs a punch - ten ...
# 4   Citrus fruit. Lots of citrus fruit. Think bloo...
# 5   An early Cocoa Psycho recipe that we loved, bu...
# 6   Hardcore IPA with raspberries aged in Caol Ila...
# 7   This beer was released as both as "Danish Beer...
# 8   From the central European plains of Germany, c...
# 9   Brewed with over ten different types of malt, ...
# 10  A session IPA brewed with a diverse grain bill...
# 11  Flavours and aromas you'd expect from a Stout,...
# 12  It's rumoured just a drop can calm the fierces...
# 13  Brewed for the opening of our first bar in Ita...
# 14  The beer was named Bracken’s Porter as a tribu...
# 15  A forgotten gem in the deepest, darkest corner...
# 16  This straight-up US style pale ale uses some o...
# 17  A perfect pale ale showcase for the tropical p...
# 18  On the nose, clove and nutmeg, cafe au lait, s...
# 19  Brewed by Chris Sartori from Stone Brewing Com...
# 20  The levels of hops vary throughout the range. ...
# 21  Deconstructed whisky sour, reconstructed as a ...
# 22  This is the Vietnamese Coffee Edition. At 12.7...
# 23  Trashy Blonde with a Belgian Twist. Clove oil,...
# 24  Never Mind the Anabolics, a 6.5% India Pale Al...
#
#                                 image_url    abv  ibu  target_fg  target_og  \
# 0    https://images.punkapi.com/v2/51.png   5.50   20       1005     1048.0
# 1    https://images.punkapi.com/v2/52.png  10.00   55       1014     1090.0
# 2   https://images.punkapi.com/v2/keg.png   4.50   35       1013     1048.0
# 3    https://images.punkapi.com/v2/54.png   7.40   65       1012     1069.0
# 4    https://images.punkapi.com/v2/55.png   7.20   70       1012     1067.0
# 5    https://images.punkapi.com/v2/56.png   9.50   85       1022     1095.0
# 6    https://images.punkapi.com/v2/57.png   9.20  149       1014     1083.0
# 7    https://images.punkapi.com/v2/58.png   9.00   65       1019     1080.0
# 8    https://images.punkapi.com/v2/59.png   7.20  100       1010     1064.0
# 9    https://images.punkapi.com/v2/60.png   7.50   30       1023     1080.0
# 10   https://images.punkapi.com/v2/61.png   4.60   30       1008     1043.0
# 11   https://images.punkapi.com/v2/62.png  10.43   65       1016     1095.0
# 12   https://images.punkapi.com/v2/63.png   7.10   68       1010     1056.0
# 13   https://images.punkapi.com/v2/64.png   8.00   35       1016     1077.0
# 14  https://images.punkapi.com/v2/keg.png   5.00   50       1010     1049.0
# 15   https://images.punkapi.com/v2/66.png  13.20   85       1023     1125.0
# 16   https://images.punkapi.com/v2/67.png   5.40   35       1008     1050.0
# 17  https://images.punkapi.com/v2/keg.png   4.10   65       1010     1042.0
# 18   https://images.punkapi.com/v2/69.png  10.60   55       1012     1090.0
# 19  https://images.punkapi.com/v2/keg.png  10.20   50       1102     1026.0
# 20   https://images.punkapi.com/v2/71.png   4.00   35       1010     1041.0
# 21  https://images.punkapi.com/v2/keg.png   7.00   20       1021     1081.0
# 22   https://images.punkapi.com/v2/73.png  12.70   85       1038     1113.5
# 23  https://images.punkapi.com/v2/keg.png   4.10   52       1010     1041.0
# 24   https://images.punkapi.com/v2/75.png   6.50   35       1012     1050.0
#
#     ...     srm   ph  attenuation_level                           volume  \
# 0   ...    7.00  4.2              89.60  {'value': 20, 'unit': 'litres'}
# 1   ...  152.00  4.4              84.40  {'value': 20, 'unit': 'litres'}
# 2   ...   20.00  4.4              72.90  {'value': 20, 'unit': 'litres'}
# 3   ...   30.00  4.2              82.60  {'value': 20, 'unit': 'litres'}
# 4   ...   15.00  4.4              82.10  {'value': 20, 'unit': 'litres'}
# 5   ...  125.00  4.4              76.80  {'value': 20, 'unit': 'litres'}
# 6   ...    9.80  4.4              83.00  {'value': 20, 'unit': 'litres'}
# 7   ...   49.00  4.4              76.00  {'value': 20, 'unit': 'litres'}
# 8   ...    6.00  4.4              84.00  {'value': 20, 'unit': 'litres'}
# 9   ...   23.00  4.5              70.00  {'value': 20, 'unit': 'litres'}
# 10  ...    7.50  4.4              81.40  {'value': 20, 'unit': 'litres'}
# 11  ...   11.50  4.4              83.20  {'value': 20, 'unit': 'litres'}
# 12  ...    7.00  4.4              82.10  {'value': 20, 'unit': 'litres'}
# 13  ...    7.50  4.4              79.20  {'value': 20, 'unit': 'litres'}
# 14  ...   55.00  4.4              79.00  {'value': 20, 'unit': 'litres'}
# 15  ...   71.00  4.4              82.17  {'value': 20, 'unit': 'litres'}
# 16  ...    5.75  4.4              84.00  {'value': 20, 'unit': 'litres'}
# 17  ...    8.50  4.4              76.20  {'value': 20, 'unit': 'litres'}
# 18  ...   15.00  4.4              86.70  {'value': 20, 'unit': 'litres'}
# 19  ...  100.00  4.4              74.50  {'value': 20, 'unit': 'litres'}
# 20  ...   22.50  5.2              75.60  {'value': 20, 'unit': 'litres'}
# 21  ...    6.00  3.2              74.00  {'value': 20, 'unit': 'litres'}
# 22  ...  125.00  5.2              76.80  {'value': 20, 'unit': 'litres'}
# 23  ...    8.50  5.2              76.00  {'value': 20, 'unit': 'litres'}
# 24  ...   11.50  4.4              76.00  {'value': 20, 'unit': 'litres'}
#
#                         boil_volume  \
# 0   {'value': 25, 'unit': 'litres'}
# 1   {'value': 25, 'unit': 'litres'}
# 2   {'value': 25, 'unit': 'litres'}
# 3   {'value': 25, 'unit': 'litres'}
# 4   {'value': 25, 'unit': 'litres'}
# 5   {'value': 25, 'unit': 'litres'}
# 6   {'value': 25, 'unit': 'litres'}
# 7   {'value': 25, 'unit': 'litres'}
# 8   {'value': 25, 'unit': 'litres'}
# 9   {'value': 25, 'unit': 'litres'}
# 10  {'value': 25, 'unit': 'litres'}
# 11  {'value': 25, 'unit': 'litres'}
# 12  {'value': 25, 'unit': 'litres'}
# 13  {'value': 25, 'unit': 'litres'}
# 14  {'value': 25, 'unit': 'litres'}
# 15  {'value': 25, 'unit': 'litres'}
# 16  {'value': 25, 'unit': 'litres'}
# 17  {'value': 25, 'unit': 'litres'}
# 18  {'value': 25, 'unit': 'litres'}
# 19  {'value': 25, 'unit': 'litres'}
# 20  {'value': 25, 'unit': 'litres'}
# 21  {'value': 25, 'unit': 'litres'}
# 22  {'value': 25, 'unit': 'litres'}
# 23  {'value': 25, 'unit': 'litres'}
# 24  {'value': 25, 'unit': 'litres'}
#
#                                                method  \
# 0   {'mash_temp': [{'temp': {'value': 63, 'unit': ...
# 1   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 2   {'mash_temp': [{'temp': {'value': 66, 'unit': ...
# 3   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 4   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 5   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 6   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 7   {'mash_temp': [{'temp': {'value': 64, 'unit': ...
# 8   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 9   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 10  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 11  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 12  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 13  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 14  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 15  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 16  {'mash_temp': [{'temp': {'value': 63, 'unit': ...
# 17  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 18  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 19  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 20  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 21  {'mash_temp': [{'temp': {'value': 60, 'unit': ...
# 22  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 23  {'mash_temp': [{'temp': {'value': 66, 'unit': ...
# 24  {'mash_temp': [{'temp': {'value': 68, 'unit': ...
#
#                                           ingredients  \
# 0   {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 1   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 2   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 3   {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 4   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 5   {'malt': [{'name': 'Extra Pale - Spring Blend'...
# 6   {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 7   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 8   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 9   {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 10  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 11  {'malt': [{'name': 'Maris Otter Extra Pale', '...
# 12  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 13  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 14  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 15  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 16  {'malt': [{'name': 'Maris Otter Extra Pale', '...
# 17  {'malt': [{'name': 'Maris Otter Extra Pale', '...
# 18  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 19  {'malt': [{'name': 'Pale Ale - Tipple', 'amoun...
# 20  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 21  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 22  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 23  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 24  {'malt': [{'name': 'Extra Pale - Spring Blend'...
#
#                                          food_pairing  \
# 0   [Tom yum soup, Andhra chicken pickle curry, Bu...
# 1   [Ancho chilli beef taco, Chocolate gateaux, Ru...
# 2   [French onion soup, Braised pheasant, Caramel ...
# 3   [Rocket and mozzarella salad with a cracked pe...
# 4   [Bratwurst sausage with spicy mustard, Fried A...
# 5   [Beef chilli made with cocoa powder, Dark choc...
# 6   [Strong blue cheese, Cranachan, Chicago style ...
# 7   [Gooey chocolate brownies, Chicken fried steak...
# 8   [Lavender and thyme roast beef, Spicy kung po ...
# 9   [Mature cheddar with red onion chutney, Honey ...
# 10  [Halibut with caper brown butter, Creamy gorgo...
# 11  [Caramelised scallops with burnt apple puree, ...
# 12  [Salt baked cod with lemon and dill butter, Be...
# 13  [Seared lemon and herb salmon, Crab linguine, ...
# 14  [Grilled vegetable and chicken teriyaki skewer...
# 15  [Duck liver paté, Mutton stew, Kirsch chocola...
# 16  [Monterey Jack stuffed grilled jalepenos, Barb...
# 17  [Quince cheese, Shredded chicken and mango sal...
# 18  [Roasted duck, Gorgonzola and rye nut bread wi...
# 19  [Lapin aux pruneaux (braised rabbit with prune...
# 20  [Roast chicken with vegetables and wild rice, ...
# 21  [Potted fresh & smoked salmon, Spiced nut loaf...
# 22  [Bacon sandwich with brown sauce, 20hr smoked ...
# 23     [Grilled fish salad, Angelfood cake, Pad Thai]
# 24  [Grilled chicken salad with bacon and avocado,...
#
#                                          brewers_tips  \
# 0   For a fresh and fiery hit, put some ginger int...
# 1   The beauty of this beer is in how brilliantly ...
# 2   The addition of Weyermann Beech Smoked malt cr...
# 3   20% specialty malts in this grist can create p...
# 4   Use the freshest hops for the most impact. It ...
# 5   There is a huge amount of roasted malts in thi...
# 6   Soak some oak chips in Caol Ila whisky to get ...
# 7   Grind the coffee as if making an espresso to r...
# 8   We've mentioned the importance of fresh hops p...
# 9   There's a lot of specialty malt in the mash. M...
# 10  Start the fermentation off at 20 ̊C and allow ...
# 11  Add all twist ingredients to Fermentation Vess...
# 12  Keep the fermentation temperature as steady as...
# 13  Sit this beer aside for a month to allow it to...
# 14  Try to replicate London’s highly carbonated wa...
# 15  Leave on wood for as long as you dare. If poss...
# 16  To dry the beer out, mash at a slightly lower ...
# 17  After the beer has fermented, leave it to rest...
# 18  For the traditional cellering, age this beer i...
# 19  Take small volume of wort out of the run off a...
# 20  Create balance through experimentation with th...
# 21                            Lemon poppyseed donuts.
# 22  Buying top notch coffee beans make a huge diff...
# 23  Don't be scared to let the fermentation temper...
# 24  Mix the powders into a paste before adding to ...
#
#               contributed_by
# 0     Sam Mason <samjbmason>
# 1     Sam Mason <samjbmason>
# 2   Ali Skinner <AliSkinner>
# 3    Matt Ball <GeordieMatt>
# 4     Sam Mason <samjbmason>
# 5     Sam Mason <samjbmason>
# 6     Sam Mason <samjbmason>
# 7     Sam Mason <samjbmason>
# 8     Sam Mason <samjbmason>
# 9   Ali Skinner <AliSkinner>
# 10    Sam Mason <samjbmason>
# 11    Sam Mason <samjbmason>
# 12    Sam Mason <samjbmason>
# 13    Sam Mason <samjbmason>
# 14    Sam Mason <samjbmason>
# 15    Sam Mason <samjbmason>
# 16    Sam Mason <samjbmason>
# 17    Sam Mason <samjbmason>
# 18  Ali Skinner <AliSkinner>
# 19    Sam Mason <samjbmason>
# 20    Sam Mason <samjbmason>
# 21    Sam Mason <samjbmason>
# 22    Sam Mason <samjbmason>
# 23    Sam Mason <samjbmason>
# 24    Sam Mason <samjbmason>
#
# [25 rows x 21 columns]

# %% [markdown]
# ## 과제 2 컨퍼런스 혹은 신입기수 세션에서 데이터를 끌어올 수 있는 API를 찾아보시고 찾기!
#
#
#
# - response 응답의 구조를 파악하여 어떤 열을 어떻게 활용할 수 있을지 적어보세요!
#
# - 찾은 API 명세서 -> 활용방안을 적어주시면 됩니다!

# %% [markdown]
# 추천 :
#
# 요즘은 다른 거를 가져다가 쓰는 게 또 능력이죠
#
# ### <https://www.reddit.com/dev/api/>
#
# ### <https://developers.kakao.com/>
#
# ### <https://developers.naver.com/main/>
#
# ### <https://platform.openai.com/docs/introduction>

# %% [markdown]
# # 아래 작성해주시면 됩니다!!

# %% [markdown]
# ### 사용할 API : https://openapi.naver.com/
# 네이버 API
#
# ### 사용할 기능 또는 api 응답에서 제공되는 변수 :
# title: 블로그 포스트 제목
# description: 블로그 포스트 내용 요약
# bloggername: 블로거 이름
# postdate: 블로그 포스트 작성 날짜
#
# ### 활용 방안 : 네이버 지도, 카카오맵, 구글 지도에 관한 사용자들의 평가, 그리고 각 앱을 사용하는 상황을 네이버 블로그를 크롤링하여 데이터 수집.

# %% [markdown]
# # 출처
#
# - 내머리
# - 챗지피티
